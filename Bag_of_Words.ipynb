# %% [markdown]
# # Bag of Words
# ## In Class
# ### English Corpus

# %%
import pandas as pd
import numpy as np
import nltk
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import jieba
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('./text_analysis_twitter.csv', index_col=0)

# %%
df
# Out:
#                         id      screen_name                       time  \
# 0       881004944714866688     KamalaHarris  2017-07-01T00:22:01-04:00
# 1       881002538341986304       MarcVeasey  2017-07-01T00:12:28-04:00
# 2       881001393284419584     RepPaulTonko  2017-07-01T00:07:55-04:00
# 3       881000301007958016        clairecmc  2017-07-01T00:03:34-04:00
# 4       881015727540637696          tedcruz  2017-07-01T01:04:52-04:00
# ...                    ...              ...                        ...
# 299995  939743413909549056       RepTedLieu  2017-12-10T01:27:44-05:00
# 299996  939743003203301376       RepTedLieu  2017-12-10T01:26:06-05:00
# 299997  939741567706730497  JuliaBrownley26  2017-12-10T01:20:23-05:00
# 299998  939739240501596160    SteveKnight25  2017-12-10T01:11:09-05:00
# 299999  939737005180801024       RepJudyChu  2017-12-10T01:02:16-05:00
#
#                                                      link  \
# 0       https://www.twitter.com/KamalaHarris/statuses/...
# 1       https://www.twitter.com/kylegriffin1/statuses/...
# 2       https://www.twitter.com/RepPaulTonko/statuses/...
# 3       https://www.twitter.com/clairecmc/statuses/881...
# 4       https://www.twitter.com/larry_kudlow/statuses/...
# ...                                                   ...
# 299995  https://www.twitter.com/ReadyLA/statuses/93956...
# 299996  https://www.twitter.com/LAFDtalk/statuses/9397...
# 299997  https://www.twitter.com/SCE/statuses/939739240...
# 299998  https://www.twitter.com/santaclarita/statuses/...
# 299999  https://www.twitter.com/RepJudyChu/statuses/93...
#
#                                                      text               source
# 0       Republicans are trying to steal health care fr...        Sprout Social
# 1       RT @kylegriffin1 Rep. Mark Veasay has introduc...  Twitter for Android
# 2       A top U.S. science office went dark tonight. N...   Twitter for iPhone
# 3       So the fundraising quarter ends in an hour in ...     Twitter for iPad
# 4       RT @larry_kudlow Important story @SenTedCruz @...   Twitter for iPhone
# ...                                                   ...                  ...
# 299995  RT @ReadyLA REPORT FIRE DAMAGE from #CreekFire...   Twitter for iPhone
# 299996  RT @LAFDtalk Once a wildfire has burned throug...   Twitter for iPhone
# 299997  RT @SCE Update: As of 8:30pm, Saturday, about ...   Twitter Web Client
# 299998  RT @santaclarita #RyeFire Evening Update (12/9...   Twitter for iPhone
# 299999  So thankful for our hardworking firefighters. ...   Twitter for iPhone
#
# [300000 rows x 6 columns]

# %%
df.text[:100].sum()
# Out:
# 'Republicans are trying to steal health care from 22 million people in order to help the wealthiest 0.4%.RT @kylegriffin1 Rep. Mark Veasay has introduced a bill to ensure no taxpayer funds will be used to support Trump\'s Election Commission. http://pbs.twimg.com/media/DDm3PgaXcAAFBIo.jpgA top U.S. science office went dark tonight. Not good. #sciencematters https://twitter.com/elleabella1112/status/880870684485984256 QT @elleabella1112 science division out. mic drop. http://pbs.twimg.com/media/DDl7NT9XoAEeJxb.jpgSo the fundraising quarter ends in an hour in MO. I would really appreciate a $5 contribution. Thank you so much. http://clairemccaskill.com/donateRT @larry_kudlow Important story @SenTedCruz @NRO. http://www.nationalreview.com/article/449134/ted-cruz-conservative-health-care-proposal?utm_campaign=trueanthem&utm_content=595717ee04d3010ccd0c715e&utm_medium=social&utm_source=twitterThreats already higher than all of 2016!  Resist! http://thehill.com/homenews/house/340309-threats-against-lawmakers-spiked-this-yearHappy birthday @SenJoniErnst!Read @RepLouCorrea article on one of California\'s finest officers "Achieving The American Dream" https://medium.com/congressman-lou-correa/achieving-the-american-dream-1fb26950da7d #HereToStayRT @airandspace 41 years ago today, the official ribbon cutting at our Museum in DC was triggered by a spacecraft orbiting Mars! http://pbs.twimg.com/media/DDpVB1xXoAA3zHZ.jpgGreat job Daylen! #littleleague #Baseball #esva https://twitter.com/13newsnow/status/881113918986489857 QT @13NewsNow Eastern Shore Little League player invited to national MLB event http://bit.ly/2tvcp5K http://pbs.twimg.com/media/DDpYcEkWAAIwrcA.jpgJohn 14:6 Jesus said to him, "I am the way, and the truth, and the life; no one comes to the Father but through Me."RT @mattmaestas Inspired by @BenSasse today begins our 2nd Annual #pushupjuly 10,000 pushups in a month. Join the fun here https://www.facebook.com/pushupjuly2017/get \'er done. https://twitter.com/mattmaestas/status/881108201403535360 QT @mattmaestas Inspired by @BenSasse today begins our 2nd Annual #pushupjuly 10,000 pushups in a month. Join the fun here https://www.facebook.com/pushupjuly2017/top o\' the morning to you as well https://twitter.com/GrizzlyHolden/status/881081323288313856 QT @GrizzlyHolden @BenSasse  http://pbs.twimg.com/tweet_video_thumb/DDo6yT_V0AAnHb4.jpg https://video.twimg.com/tweet_video/DDo6yT_V0AAnHb4.mp4TMI https://twitter.com/guyindelco/status/881092215799414784 QT @guyindelco @BenSasse I always get the pork chops for breakfast at Cracker Barrel....b/c when we people disagree about policy, the winning move is to call them monsters &amp; scream the other side\'s goal is to kill people... https://twitter.com/PalmerReport/status/880949703122309122 QT @PalmerReport For those of you who thought Ben Sasse wasn\'t a monster... https://twitter.com/BenSasse/status/880745889266106368Join with me and tell @SOSCegavske to protect our information from Trump and his insecurities.  https://www.usnews.com/news/best-states/nevada/articles/2017-06-30/nevada-to-provide-public-data-comply-with-voter-fraud-probe?src=usn_twreally good on dialogue and listening by @timkellernyc https://twitter.com/BenSasse/status/881109096140873730 QT @BenSasse "we shouldn\'t talk until we can represent the skeptic’s viewpoint with empathy so he says, ‘Yes, that\'s my hang up\'"\nhttp://www.christianitytoday.com/ct/2017/june/why-we-argue-best-with-our-mouths-shut.html"we shouldn\'t talk until we can represent the skeptic’s viewpoint with empathy so he says, ‘Yes, that\'s my hang up\'"\nhttp://www.christianitytoday.com/ct/2017/june/why-we-argue-best-with-our-mouths-shut.htmlamazing story / kid / family https://twitter.com/BenSasse/status/881106096081051650 QT @BenSasse “He didn’t complain abt having cancer” his dad said. “He was thankful for having it so he could reach out to others"\nhttp://www.omaha.com/livewellnebraska/recent-grad-simon-jones-who-wrote-blog-about-his-cancer/ ...

# %%
tokenizer = TweetTokenizer()
lemmatizer = WordNetLemmatizer()

nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'http\S+','',text)
    tokens = tokenizer.tokenize(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and token != 'rt' and token not in stop_words]
    return tokens

# %%
df['preprocessed_text'] = df['text'].apply(preprocess_text)

# %%
df.head()
# Out:
#                    id   screen_name                       time  \
# 0  881004944714866688  KamalaHarris  2017-07-01T00:22:01-04:00
# 1  881002538341986304    MarcVeasey  2017-07-01T00:12:28-04:00
# 2  881001393284419584  RepPaulTonko  2017-07-01T00:07:55-04:00
# 3  881000301007958016     clairecmc  2017-07-01T00:03:34-04:00
# 4  881015727540637696       tedcruz  2017-07-01T01:04:52-04:00
#
#                                                 link  \
# 0  https://www.twitter.com/KamalaHarris/statuses/...
# 1  https://www.twitter.com/kylegriffin1/statuses/...
# 2  https://www.twitter.com/RepPaulTonko/statuses/...
# 3  https://www.twitter.com/clairecmc/statuses/881...
# 4  https://www.twitter.com/larry_kudlow/statuses/...
#
#                                                 text               source  \
# 0  Republicans are trying to steal health care fr...        Sprout Social
# 1  RT @kylegriffin1 Rep. Mark Veasay has introduc...  Twitter for Android
# 2  A top U.S. science office went dark tonight. N...   Twitter for iPhone
# 3  So the fundraising quarter ends in an hour in ...     Twitter for iPad
# 4  RT @larry_kudlow Important story @SenTedCruz @...   Twitter for iPhone
#
#                                    preprocessed_text
# 0  [republican, trying, steal, health, care, mill...
# 1  [rep, mark, veasay, introduced, bill, ensure, ...
# 2  [top, u, science, office, went, dark, tonight,...
# 3  [fundraising, quarter, end, hour, mo, would, r...
# 4                                 [important, story]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['preprocessed_text'].apply(lambda x:str(x)))

# %%
X.shape
# Out:
# (300000, 50343)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['aa', 'aaa', 'aaaa', ..., '투표하십시오', '한국어', 'ﬂees'], dtype=object)

# %% [markdown]
# ### Chinese Corpus

# %%
import pandas as pd
import numpy as np
import jieba
import nltk
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('./text_analysis_weibo.csv', index_col=0)

# %%
df.head()
# Out:
#                                              标题/微博内容  点赞  转发  评论  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​   0   0   0
# 1                                                转发C   0   0   0
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...   0   0   0
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...   0   0   0
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！   0   0   0
#
#                           账号昵称UID加密  粉丝数   关注数  地域
# 0  a2331b38901d62d2d9a20529177ef3b3    0    22  湖北
# 1  d6dc4470f51fce93cc0cbad8abf55a75    0    33  广西
# 2  372bc4782eb442b88035f920a7c1a68e    6    85  广东
# 3  6fe0d482bd3e78a3483e2a1d57f14ef2   75  1012  广东
# 4  872380d71d6ee9130e8b49d331f2baa9    0    10  广东

# %%
def remove_nums(text):
    nonums = re.sub('[^\u4e00-\u9fa5]+', '', text)
    return nonums
test = df['标题/微博内容'][0]
remove_nums(test)
# Out:
# '高校通报教师图书馆打电话声音过大出言不逊公道自在人心谣言自在人心'

# %%
stopwords = open('stopwords.txt', encoding = 'utf-8').read()
def clean_text(text):
    words = jieba.lcut(text)
    words = [w for w in words if w not in stopwords and w!='\u200b' and w!='转发']
    return ' '.join(words)
test = df['标题/微博内容'][0]
clean_text(test)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/7d/507_52mn2sv4475h6l1k244c0000gn/T/jieba.cache
# Loading model cost 0.333 seconds.
# Prefix dict has been built successfully.
# '高校 通报 教师 图书馆 打电话 声音 过大 出言不逊 公道 人心 谣言 人心'

# %%
words = pd.DataFrame(df['标题/微博内容'].astype(str))
words.head()
# Out:
#                                              标题/微博内容
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​
# 1                                                转发C
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！

# %%
def countwords(text):
    nonums = re.sub('[^\u4e00-\u9fa5]+', '', text)
    char_count = len(nonums)
    return char_count
test = df['标题/微博内容'][30]
countwords(test)
# Out:
# 5

# %%
words
# Out:
#                                                  标题/微博内容
# 0                 #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​
# 1                                                    转发C
# 2      【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...
# 3      丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...
# 4                            诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！
# ...                                                  ...
# 49995  935天气路况早知道 2022年3月2日 星期三 今日限行尾号3和8 8：00分发布    ...
# 49996        4月1日起，交通违法记分规则重大调整！ http://t.cn/A66zxfR0 ​​
# 49997                                                转发C
# 49998      全体     甘肃车主注意       4月1日起，全面实施！           ...
# 49999  【南通司机注意！4月1日起，记分规则重大调整】​驾车拨打、接听电话妨碍安全驾驶的，由一次性记...
#
# [50000 rows x 1 columns]

# %%
words['character_count'] = words['标题/微博内容'].apply(countwords)
words.head()
# Out:
#                                              标题/微博内容  character_count
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19

# %%
def tag_extraction(text):
    tags = re.findall(r'#.*?#', text)
    for t in tags:
        if '[超话]' in t:
            tags.remove(t)
    return tags
test = tag_extraction(df['标题/微博内容'][0])
print(test)
# Out:
# ['#高校通报教师图书馆打电话声音过大出言不逊#']

# %%
words['tags'] = words['标题/微博内容'].apply(tag_extraction)
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]
# 1                        []
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]
# 3         [#丁程鑫 二十成金筑梦鑫世界#]
# 4                        []

# %%
tags_count = []
for tag in words['tags']:
    tc = len(tag)
    tags_count.append(tc)
words['tags_count'] = tags_count
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags  tags_count
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]           1
# 1                        []           0
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]           2
# 3         [#丁程鑫 二十成金筑梦鑫世界#]           1
# 4                        []           0

# %%
def wbemoji_extraction(text):
    temtext = text.replace('[', '<')
    temtext = temtext.replace(']', '>')
    weibo_emoji = re.findall(r'<.*?>', temtext)
    for we in weibo_emoji:
        if we == '<超话>':
            weibo_emoji.remove(we)
    return weibo_emoji
test = wbemoji_extraction(words['标题/微博内容'][333])
test
# Out:
# ['<doge>', '<doge>']

# %%
words['weibo_emoji'] = words['标题/微博内容'].apply(wbemoji_extraction)
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags  tags_count weibo_emoji
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]           1          []
# 1                        []           0          []
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]           2      [<金牌>]
# 3         [#丁程鑫 二十成金筑梦鑫世界#]           1          []
# 4                        []           0          []

# %%
weibo_emoji_count = []
for we in words['weibo_emoji']:
    wec = len(we)
    weibo_emoji_count.append(wec)
words['weibo_emoji_count'] = weibo_emoji_count
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags  tags_count weibo_emoji  weibo_emoji_count
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]           1          []                  0
# 1                        []           0          []                  0
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]           2      [<金牌>]                  1
# 3         [#丁程鑫 二十成金筑梦鑫世界#]           1          []                  0
# 4                        []           0          []                  0

# %%
def supertalk_extraction(text):
    supertalk = []
    tempst = re.findall(r'#.*?#', text)
    for tst in tempst:
        if '[超话]' in tst:
            supertalk.append(tst)
    return supertalk
test = supertalk_extraction(words['标题/微博内容'][3])
test
# Out:
# ['#丁程鑫[超话]#']

# %%
words['supertalks'] = words['标题/微博内容'].apply(supertalk_extraction)
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags  tags_count weibo_emoji  weibo_emoji_count  \
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]           1          []                  0
# 1                        []           0          []                  0
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]           2      [<金牌>]                  1
# 3         [#丁程鑫 二十成金筑梦鑫世界#]           1          []                  0
# 4                        []           0          []                  0
#
#     supertalks
# 0           []
# 1           []
# 2           []
# 3  [#丁程鑫[超话]#]
# 4           []

# %%
supertalk_count = []
for st in words['supertalks']:
    stc = len(st)
    supertalk_count.append(stc)
words['supertalk_count'] = supertalk_count
words.head()
# Out:
#                                              标题/微博内容  character_count  \
# 0             #高校通报教师图书馆打电话声音过大出言不逊#公道自在人心，谣言自在人心 ​​               32
# 1                                                转发C                2
# 2  【#刘雨昕运动者联濛#河山覆冰雪，健儿迎冬奥[金牌]全能唱跳不设限，运动联濛开新年🇨🇳 期待...               61
# 3  丁程鑫//@丁程鑫后援会官博:#丁程鑫[超话]# ✨#丁程鑫 二十成金筑梦鑫世界# 大年初一...               64
# 4                        诶，你们真不要脸诶。。。没资格宣传奥运。。。抵制抵制！               19
#
#                        tags  tags_count weibo_emoji  weibo_emoji_count  \
# 0  [#高校通报教师图书馆打电话声音过大出言不逊#]           1          []                  0
# 1                        []           0          []                  0
# 2     [#刘雨昕运动者联濛#, #运动者联濛#]           2      [<金牌>]                  1
# 3         [#丁程鑫 二十成金筑梦鑫世界#]           1          []                  0
# 4                        []           0          []                  0
#
#     supertalks  supertalk_count
# 0           []                0
# 1           []                0
# 2           []                0
# 3  [#丁程鑫[超话]#]                1
# 4           []                0

# %%
text = words['标题/微博内容'].apply(clean_text)

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(text)

# %%
feature_words = vectorizer.get_feature_names_out()

# %%
word_freq = dict(zip(feature_words,X.sum(axis=0).A1))

# %%
sorted(word_freq.items(),key = lambda x:x[1], reverse=True)
# Out:
# [('发展', 52421),
#  ('建设', 38186),
#  ('中国', 37685),
#  ('企业', 36472),
#  ('市场', 35827),
#  ('汽车', 30384),
#  ('2022', 29315),
#  ('增长', 26601),
#  ('经济', 25205),
#  ('亿元', 22701),
#  ('项目', 21717),
#  ('国家', 21290),
#  ('政策', 21258),
#  ('工作', 21089),
#  ('10', 20832),
#  ('服务', 19591),
#  ('新能源', 19181),
#  ('同比', 19083),
#  ('投资', 19015),
#  ('推进', 18856),
#  ('行业', 18277),
#  ('产业', 17422),
#  ('提升', 17384),
#  ('产品', 16814),
#  ('数据', 16807),
#  ('推动', 15882),
#  ('2021', 15693),
#  ('持续', 15494),
#  ('技术', 14423),
#  ('nbsp', 14154),
#  ('全国', 13998),
#  ('全球', 13897),
#  ('创新', 13695),
#  ('支持', 13655),
#  ('疫情', 13574),
#  ('11', 13129),
#  ('城市', 13074),
#  ('需求', 13039),
#  ('加快', 12477),
#  ('国际', 12346),
#  ('发布', 12308),
#  ('国内', 12218),
#  ('12', 12139),
#  ('一个', 12005),
#  ('相关', 11992),
#  ('实施', 11824),
#  ('领域', 11744),
#  ('理想', 11640),
#  ('影响', 11637),
#  ('生产', 11537),
#  ('品牌', 11501),
#  ('重点', 11477),
#  ('平台', 11265),
#  ('价格', 10979),
#  ('销量', 10853),
#  ('科技', 10636),
#  ('提供', 10532),
#  ('电池', 10103),
#  ('情况', 10069),
#  ('能力', 10003),
#  ('时间', 9990),
#  ('进一步', 9953),
#  ('时代', 9934),
#  ('合作', 9924),
#  ('教育', 9804),
#  ('中心', 9780),
#  ('管理', 9477),
#  ('我国', 9469),
#  ('消费', 9382),
#  ('预期', 9304),
#  ('美国', 9241),
#  ('业务', 9192),
#  ('网络', 9184),
#  ('未来', 9047),
#  ('信息', 8988),
#  ('工程', 8988),
#  ('地区', 8957),
#  ('重庆', 8641),
#  ('集团', 8572),
#  ('资金', 8556),
#  ('下降', 8527),
#  ('超过', 8506),
#  ('数字', 8500),
#  ('万元', 8475),
#  ('物流', 8384),
#  ('规模', 8216),
#  ('保障', 8113),
#  ('车型', 8074),
#  ('30', 8024),
#  ('体系', 7980),
#  ('系统', 7964),
#  ('预计', 7881),
#  ('打造', 7828),
#  ('增加', 7792),
#  ('社会', 7764),
#  ('考试', 7742),
#  ('万辆', 7632),
#  ('关注', 7578),
#  ('工业', 7570),
#  ('计划', 7568),
#  ('落实', 7563),
#  ('综合', 7520),
#  ('上半年', 7425),
#  ('优势', 7422),
#  ('战略', 7378),
#  ('交付', 7365),
#  ('风险', 7324),
#  ('智能', 7237),
#  ('显示', 7154),
#  ('股份', 7128),
#  ('考生', 7113),
#  ('产业链', 7100),
#  ('通道', 7090),
#  ('比亚迪', 6949),
#  ('生态', 6877),
#  ('15', 6842),
#  ('专业', 6827),
#  ('水平', 6822),
#  ('规划', 6780),
#  ('上涨', 6778),
#  ('环境', 6711),
#  ('提高', 6685),
#  ('万吨', 6649),
#  ('销售', 6623),
#  ('区域', 6621),
#  ('成本', 6619),
#  ('世界', 6613),
#  ('包括', 6612),
#  ('研发', 6577),
#  ('能源', 6531),
#  ('目标', 6524),
#  ('机构', 6515),
#  ('高质量', 6433),
#  ('改革', 6403),
#  ('基础设施', 6378),
#  ('资源', 6344),
#  ('基础', 6332),
#  ('月份', 6321),
#  ('绿色', 6316),
#  ('核心', 6198),
#  ('完善', 6127),
#  ('2020', 6105),
#  ('调整', 6102),
#  ('部门', 6098),
#  ('加大', 6059),
#  ('布局', 6059),
#  ('材料', 6048),
#  ('稳定', 6047),
#  ('累计', 6025),
#  ('政府', 5978),
#  ('方式', 5972),
#  ('环比', 5971),
#  ('增速', 5897),
#  ('收入', 5882),
#  ('人员', 5854),
#  ('学校', 5823),
#  ('优化', 5761),
#  ('分析', 5724),
#  ('贷款', 5724),
#  ('活动', 5678),
#  ('14', 5668),
#  ('产能', 5636),
#  ('板块', 5631),
#  ('基金', 5618),
#  ('50', 5593),
#  ('北京', 5544),
#  ('金融', 5518),
#  ('报告', 5516),
#  ('cn', 5472),
#  ('整体', 5437),
#  ('健康', 5404),
#  ('铁路', 5395),
#  ('交通', 5390),
#  ('指数', 5387),
#  ('出口', 5330),
#  ('特斯拉', 5320),
#  ('研究', 5312),
#  ('西部', 5312),
#  ('上海', 5284),
#  ('美元', 5268),
#  ('招生', 5261),
#  ('习近平', 5248),
#  ('高校', 5228),
#  ('制度', 5223),
#  ('报名', 5204),
#  ('2023', 5185),
#  ('支撑', 5173),
#  ('力度', 5165),
#  ('机制', 5162),
#  ('组织', 5136),
#  ('利率', 5100),
#  ('做好', 5090),
#  ('制造', 5064),
#  ('100', 5029),
#  ('空间', 5018),
#  ('模式', 5014),
#  ('16', 5013),
#  ('http', 5002),
#  ('制造业', 5001),
#  ('13', 4988),
#  ('建立', 4985),
#  ('退税', 4950),
#  ('突破', 4906),
#  ('人民', 4886),
#  ('留抵', 4857),
#  ('银行', 4843),
#  ('客户', 4835),
#  ('数据中心', 4824),
#  ('生活', 4820),
#  ('文化', 4794),
#  ('融资', 4794),
#  ('就业', 4788),
#  ('作用', 4776),
#  ('压力', 4765),
#  ('升级', 4763),
#  ('防控', 4755),
#  ('报考', 4746),
#  ('保护', 4744),
#  ('设备', 4730),
#  ('单位', 4698),
#  ('有限公司', 4694),
#  ('欧洲', 4694),
#  ('正式', 4681),
#  ('25', 4664),
#  ('提出', 4652),
#  ('构建', 4638),
#  ('公布', 4631),
#  ('21', 4629),
#  ('表现', 4624),
#  ('有望', 4616),
#  ('上市', 4613),
#  ('截至', 4608),
#  ('用户', 4598),
#  ('强化', 4589),
#  ('治理', 4588),
#  ('措施', 4565),
#  ('运营', 4498),
#  ('开放', 4460),
#  ('大幅', 4453),
#  ('选择', 4442),
#  ('带来', 4417),
#  ('基地', 4410),
#  ('标准', 4404),
#  ('供应链', 4398),
#  ('历史', 4370),
#  ('转型', 4367),
#  ('功能', 4362),
#  ('诈骗', 4362),
#  ('蔚来', 4298),
#  ('落地', 4297),
#  ('24', 4275),
#  ('22', 4235),
#  ('17', 4231),
#  ('车企', 4220),
#  ('特色', 4213),
#  ('专项', 4190),
#  ('公告', 4188),
#  ('传统', 4187),
#  ('内容', 4182),
#  ('下滑', 4181),
#  ('设计', 4178),
#  ('来源', 4144),
#  ('推出', 4127),
#  ('旅游', 4104),
#  ('小鹏', 4095),
#  ('互联网', 4066),
#  ('18', 4052),
#  ('条件', 4036),
#  ('新增', 4014),
#  ('人才', 4009),
#  ('会议', 4009),
#  ('回落', 4008),
#  ('库存', 4008),
#  ('乡村', 4003),
#  ('确保', 3988),
#  ('融合', 3985),
#  ('开发', 3982),
#  ('陆海', 3974),
#  ('近期', 3970),
#  ('阶段', 3940),
#  ('地方', 3937),
#  ('高端', 3937),
#  ('申请', 3911),
#  ('贸易', 3894),
#  ('学习', 3890),
#  ('快速', 3866),
#  ('全省', 3861),
#  ('趋势', 3857),
#  ('经营', 3832),
#  ('减少', 3821),
#  ('建议', 3820),
#  ('统筹', 3812),
#  ('芯片', 3791),
#  ('智慧', 3779),
#  ('23', 3777),
#  ('房地产', 3761),
#  ('格局', 3760),
#  ('儿童', 3739),
#  ('宝马', 3739),
#  ('总书记', 3733),
#  ('因素', 3717),
#  ('建成', 3715),
#  ('电子', 3707),
#  ('加息', 3695),
#  ('交易', 3682),
#  ('很多', 3681),
#  ('2019', 3667),
#  ('群众', 3666),
#  ('人民币', 3662),
#  ('班列', 3648),
#  ('通胀', 3633),
#  ('宁德', 3632),
#  ('31', 3609),
#  ('带动', 3603),
#  ('学科', 3602),
#  ('连续', 3597),
#  ('发挥', 3580),
#  ('降低', 3575),
#  ('工厂', 3573),
#  ('改善', 3558),
#  ('海外', 3546),
#  ('加速', 3543),
#  ('协同', 3535),
#  ('40', 3531),
#  ('住房', 3527),
#  ('方向', 3523),
#  ('启动', 3517),
#  ('解决', 3512),
#  ('结构', 3510),
#  ('百分点', 3504),
#  ('改造', 3499),
#  ('导致', 3497),
#  ('农业', 3496),
#  ('19', 3489),
#  ('自主', 3486),
#  ('电信', 3479),
#  ('订单', 3462),
#  ('美联储', 3456),
#  ('运行', 3455),
#  ('两个', 3451),
#  ('亿美元', 3442),
#  ('部署', 3442),
#  ('通知', 3431),
#  ('动力电池', 3425),
#  ('大学', 3418),
#  ('深化', 3402),
#  ('处于', 3401),
#  ('电商', 3398),
#  ('跨境', 3392),
#  ('德国', 3391),
#  ('资本', 3384),
#  ('进口', 3382),
#  ('供应', 3378),
#  ('动力', 3375),
#  ('成功', 3364),
#  ('下跌', 3363),
#  ('驾驶', 3363),
#  ('一流', 3350),
#  ('增强', 3346),
#  ('孩子', 3343),
#  ('变化', 3327),
#  ('现代化', 3322),
#  ('消息', 3313),
#  ('出台', 3305),
#  ('投入', 3301),
#  ('消费者', 3300),
#  ('长期', 3290),
#  ('数字化', 3285),
#  ('一体化', 3273),
#  ('关键', 3268),
#  ('农村', 3267),
#  ('养老', 3264),
#  ('方案', 3264),
#  ('26', 3263),
#  ('一批', 3262),
#  ('原因', 3261),
#  ('比例', 3256),
#  ('成立', 3245),
#  ('涨幅', 3233),
#  ('研究生', 3231),
#  ('发生', 3222),
#  ('全力', 3217),
#  ('指导', 3215),
#  ('光伏', 3208),
#  ('利用', 3208),
#  ('责任', 3203),
#  ('参与', 3201),
#  ('期间', 3200),
#  ('直播', 3197),
#  ('算力', 3192),
#  ('枢纽', 3190),
#  ('机会', 3184),
#  ('资产', 3171),
#  ('反弹', 3154),
#  ('疫苗', 3142),
#  ('新闻', 3140),
#  ('全市', 3131),
#  ('增值税', 3126),
#  ('介绍', 3119),
#  ('补贴', 3098),
#  ('28', 3094),
#  ('质量', 3075),
#  ('鼓励', 3062),
#  ('数量', 3061),
#  ('近日', 3061),
#  ('业绩', 3057),
#  ('代表', 3054),
#  ('势力', 3052),
#  ('60', 3022),
#  ('精神', 3022),
#  ('拥有', 3005),
#  ('参加', 3002),
#  ('产量', 2995),
#  ('考研', 2990),
#  ('面临', 2983),
#  ('电动', 2974),
#  ('短期', 2974),
#  ('社会主义', 2971),
#  ('过程', 2960),
#  ('开工', 2952),
#  ('检测', 2945),
#  ('计算', 2941),
#  ('培育', 2940),
#  ('成绩', 2937),
#  ('恢复', 2928),
#  ('运输', 2926),
#  ('覆盖', 2921),
#  ('震荡', 2920),
#  ('20', 2915),
#  ('净利润', 2908),
#  ('政治', 2905),
#  ('低于', 2903),
#  ('配套', 2902),
#  ('引导', 2880),
#  ('联合', 2868),
#  ('较大', 2865),
#  ('这是', 2850),
#  ('行情', 2849),
#  ('教师', 2835),
#  ('cpi', 2830),
#  ('策略', 2829),
#  ('安排', 2827),
#  ('中央', 2826),
#  ('周期', 2821),
#  ('利润', 2792),
#  ('发现', 2791),
#  ('竞争', 2783),
#  ('供给', 2779),
#  ('助力', 2774),
#  ('围绕', 2769),
#  ('监管', 2768),
#  ('学生', 2752),
#  ('指出', 2748),
#  ('聚焦', 2748),
#  ('四川', 2732),
#  ('价值', 2724),
#  ('民生', 2717),
#  ('2025', 2707),
#  ('首次', 2704),
#  ('27', 2685),
#  ('年度', 2672),
#  ('新型', 2670),
#  ('协调', 2659),
#  ('整治', 2651),
#  ('29', 2645),
#  ('示范', 2645),
#  ('统一', 2645),
#  ('高效', 2641),
#  ('l9', 2635),
#  ('振兴', 2619),
#  ('国务院', 2617),
#  ('拓展', 2616),
#  ('下游', 2611),
#  ('营收', 2611),
#  ('科学', 2610),
#  ('商品', 2603),
#  ('办理', 2599),
#  ('日本', 2599),
#  ('希望', 2594),
#  ('小时', 2586),
#  ('试点', 2586),
#  ('各类', 2583),
#  ('医疗', 2582),
#  ('车辆', 2581),
#  ('最新', 2576),
#  ('引领', 2574),
#  ('成都', 2573),
#  ('大型', 2570),
#  ('港口', 2564),
#  ('公里', 2551),
#  ('系列', 2549),
#  ('家庭', 2548),
#  ('着力', 2546),
#  ('迎来', 2524),
#  ('相比', 2517),
#  ('意见', 2515),
#  ('努力', 2514),
#  ('规范', 2513),
#  ('针对', 2509),
#  ('投资者', 2508),
#  ('自动', 2498),
#  ('华为', 2491),
#  ('a股', 2487),
#  ('万亿元', 2479),
#  ('控制', 2478),
#  ('500', 2477),
#  ('养老金', 2474),
#  ('盈利', 2472),
#  ('更好', 2462),
#  ('教育部', 2448),
#  ('优质', 2443),
#  ('领导', 2443),
#  ('平均', 2431),
#  ('执行', 2431),
#  ('总体', 2421),
#  ('关系', 2418),
#  ('充电', 2409),
#  ('排名', 2409),
#  ('全年', 2403),
#  ('45', 2402),
#  ('采用', 2401),
#  ('制定', 2396),
#  ('电动车', 2396),
#  ('one', 2391),
#  ('零部件', 2390),
#  ('一路', 2389),
#  ('此前', 2388),
#  ('山东', 2381),
#  ('视频', 2371),
#  ('东数', 2368),
#  ('80', 2364),
#  ('中欧', 2364),
#  ('储能', 2361),
#  ('多个', 2361),
#  ('十四五', 2355),
#  ('年底', 2355),
#  ('探索', 2354),
#  ('西算', 2352),
#  ('精准', 2344),
#  ('进出口', 2343),
#  ('成果', 2342),
#  ('证券', 2336),
#  ('困难', 2323),
#  ('宣传', 2323),
#  ('程度', 2323),
#  ('服务业', 2321),
#  ('期货', 2319),
#  ('一年', 2310),
#  ('用于', 2309),
#  ('渠道', 2308),
#  ('具备', 2293),
#  ('大众', 2293),
#  ('一是', 2291),
#  ('外贸', 2289),
#  ('释放', 2288),
#  ('乘用车', 2287),
#  ('思想', 2281),
#  ('符合', 2276),
#  ('人数', 2273),
#  ('场景', 2270),
#  ('超话', 2263),
#  ('下半年', 2260),
#  ('主体', 2260),
#  ('印发', 2260),
#  ('厂商', 2259),
#  ('操作', 2259),
#  ('二是', 2257),
#  ('培训', 2254),
#  ('采购', 2237),
#  ('设施', 2235),
#  ('2018', 2233),
#  ('回升', 2229),
#  ('机遇', 2227),
#  ('现货', 2226),
#  ('越来越', 2226),
#  ('增量', 2224),
#  ('智能化', 2220),
#  ('新车', 2219),
#  ('suv', 2213),
#  ('70', 2211),
#  ('购买', 2211),
#  ('燃油', 2201),
#  ('走势', 2199),
#  ('近年来', 2198),
#  ('估值', 2194),
#  ('理念', 2191),
#  ('省级', 2189),
#  ('硕士', 2184),
#  ('税额', 2182),
#  ('gdp', 2181),
#  ('法律', 2180),
#  ('黄金', 2179),
#  ('毛利率', 2178),
#  ('依然', 2176),
#  ('俄罗斯', 2175),
#  ('广西', 2175),
#  ('成渝', 2165),
#  ('效率', 2163),
#  ('零售', 2155),
#  ('驱动', 2154),
#  ('咨询', 2148),
#  ('来自', 2148),
#  ('发行', 2144),
#  ('举措', 2143),
#  ('共建', 2143),
#  ('指标', 2143),
#  ('网上', 2143),
#  ('预测', 2140),
#  ('竞争力', 2138),
#  ('半导体', 2133),
#  ('提前', 2132),
#  ('深度', 2121),
#  ('经济社会', 2120),
#  ('交通运输', 2119),
#  ('十年', 2118),
#  ('35', 2114),
#  ('存量', 2110),
#  ('货物', 2095),
#  ('集群', 2090),
#  ('造车', 2089),
#  ('冲击', 2079),
#  ('修复', 2077),
#  ('先进', 2077),
#  ('2017', 2072),
#  ('维护', 2069),
#  ('成长', 2067),
#  ('文明', 2066),
#  ('贵州', 2066),
#  ('公开', 2062),
#  ('职业', 2061),
#  ('软件', 2059),
#  ('体验', 2052),
#  ('电力', 2051),
#  ('孤独症', 2048),
#  ('统计', 2048),
#  ('hpv', 2046),
#  ('支付', 2045),
#  ('区间', 2041),
#  ('媒体', 2037),
#  ('配置', 2031),
#  ('开启', 2029),
#  ('波动', 2028),
#  ('依法', 2025),
#  ('再次', 2021),
#  ('社区', 2015),
#  ('90', 2014),
#  ('力量', 2013),
#  ('协议', 2013),
#  ('老师', 2010),
#  ('今日', 2007),
#  ('三个', 2006),
#  ('居民', 1996),
#  ('地产', 1994),
#  ('给予', 1992),
#  ('未成年人', 1991),
#  ('后续', 1987),
#  ('市场主体', 1985),
#  ('高速', 1985),
#  ('学院', 1984),
#  ('招聘', 1978),
#  ('有序', 1968),
#  ('装备', 1967),
#  ('最终', 1960),
#  ('一带', 1957),
#  ('合约', 1957),
#  ('现场', 1957),
#  ('营业', 1957),
#  ('情绪', 1953),
#  ('新区', 1949),
#  ('高铁', 1949),
#  ('新冠', 1947),
#  ('下调', 1939),
#  ('贯彻', 1939),
#  ('官方', 1936),
#  ('对接', 1933),
#  ('33', 1929),
#  ('原材料', 1929),
#  ('实践', 1929),
#  ('举办', 1925),
#  ('享受', 1925),
#  ('推广', 1921),
#  ('利好', 1914),
#  ('节点', 1914),
#  ('挑战', 1911),
#  ('供应商', 1905),
#  ('如今', 1905),
#  ('商业', 1904),
#  ('背景', 1904),
#  ('涉及', 1902),
#  ('高水平', 1901),
#  ('5g', 1900),
#  ('亏损', 1900),
#  ('纳税人', 1900),
#  ('龙头', 1896),
#  ('旗下', 1895),
#  ('要素', 1895),
#  ('月底', 1891),
#  ('经验', 1883),
#  ('财政部', 1878),
#  ('基于', 1877),
#  ('纳入', 1877),
#  ('定位', 1871),
#  ('评估', 1871),
#  ('信心', 1866),
#  ('申报', 1864),
#  ('基点', 1863),
#  ('团队', 1858),
#  ('金额', 1858),
#  ('依托', 1856),
#  ('资格', 1854),
#  ('发力', 1853),
#  ('出行', 1852),
#  ('深圳', 1852),
#  ('广州', 1851),
#  ('健全', 1848),
#  ('监测', 1847),
#  ('主题', 1844),
#  ('主动', 1841),
#  ('确认', 1841),
#  ('高位', 1839),
#  ('各项', 1838),
#  ('创业', 1837),
#  ('设立', 1837),
#  ('交流', 1834),
#  ('打击', 1825),
#  ('党中央', 1819),
#  ('接受', 1817),
#  ('主流', 1815),
#  ('此次', 1815),
#  ('环节', 1815),
#  ('下行', 1808),
#  ('状态', 1805),
#  ('东方', 1804),
#  ('整车', 1802),
#  ('毕业生', 1802),
#  ('金融机构', 1801),
#  ('公路', 1798),
#  ('实行', 1797),
#  ('这一', 1793),
#  ('天津', 1790),
#  ('三季度', 1789),
#  ('基层', 1788),
#  ('道路', 1786),
#  ('300', 1784),
#  ('领先', 1775),
#  ('联运', 1771),
#  ('证明', 1769),
#  ('位于', 1767),
#  ('信息化', 1767),
#  ('电动汽车', 1765),
#  ('态势', 1763),
#  ('资料', 1761),
#  ('一系列', 1760),
#  ('三是', 1759),
#  ('负责', 1759),
#  ('同期', 1756),
#  ('1000', 1752),
#  ('建筑', 1751),
#  ('面对', 1750),
#  ('国产', 1747),
#  ('转移', 1743),
#  ('债券', 1737),
#  ('大会', 1737),
#  ('试验区', 1732),
#  ('扎实', 1731),
#  ('锂电池', 1727),
#  ('财经', 1724),
#  ('创建', 1721),
#  ('新高', 1719),
#  ('审核', 1717),
#  ('01', 1713),
#  ('共享', 1713),
#  ('放缓', 1712),
#  ('医院', 1706),
#  ('原则', 1706),
#  ('意味着', 1704),
#  ('真的', 1704),
#  ('监督', 1699),
#  ('广东', 1698),
#  ('创造', 1697),
#  ('发布会', 1697),
#  ('75', 1696),
#  ('园区', 1696),
#  ('赛道', 1693),
#  ('哪吒', 1690),
#  ('实力', 1685),
#  ('原油', 1682),
#  ('股票', 1681),
#  ('大盘', 1679),
#  ('今年以来', 1678),
#  ('长江', 1677),
#  ('城乡', 1675),
#  ('市值', 1674),
#  ('基建', 1671),
#  ('渗透率', 1667),
#  ('央行', 1665),
#  ('法治', 1665),
#  ('手机', 1662),
#  ('人口', 1660),
#  ('岗位', 1659),
#  ('高于', 1657),
#  ('日前', 1655),
#  ('联动', 1654),
#  ('延续', 1653),
#  ('费用', 1653),
#  ('股价', 1651),
#  ('低碳', 1650),
#  ('本次', 1648),
#  ('年内', 1645),
#  ('煤炭', 1644),
#  ('家长', 1642),
#  ('入学', 1639),
#  ('一步', 1638),
#  ('事项', 1638),
#  ('口岸', 1634),
#  ('货运', 1633),
#  ('效应', 1630),
#  ('贯彻落实', 1623),
#  ('审批', 1621),
#  ('当地', 1620),
#  ('32', 1615),
#  ('36', 1610),
#  ('发放', 1610),
#  ('贡献', 1609),
#  ('呈现', 1608),
#  ('主力', 1607),
#  ('青年', 1607),
#  ('速度', 1605),
#  ('上游', 1603),
#  ('核酸', 1602),
#  ('生物', 1602),
#  ('食品', 1600),
#  ('负责人', 1598),
#  ('位置', 1595),
#  ('自闭症', 1595),
#  ('即将', 1590),
#  ('通信', 1586),
#  ('防疫', 1585),
#  ('营销', 1583),
#  ('产业园', 1581),
#  ('一种', 1579),
#  ('形势', 1575),
#  ('万人', 1574),
#  ('最低', 1574),
#  ('公共', 1571),
#  ('义务教育', 1570),
#  ('叠加', 1568),
#  ('犯罪', 1567),
#  ('上汽', 1566),
#  ('作出', 1563),
#  ('平稳', 1562),
#  ('注册', 1560),
#  ('48', 1559),
#  ('面试', 1558),
#  ('专家', 1554),
#  ('国家级', 1546),
#  ('中小企业', 1543),
#  ('上市公司', 1541),
#  ('畅通', 1541),
#  ('装置', 1541),
#  ('飞机', 1539),
#  ('引进', 1537),
#  ('我市', 1537),
#  ('报道', 1537),
#  ('办法', 1536),
#  ('地位', 1535),
#  ('机场', 1535),
#  ('江苏', 1533),
#  ('体现', 1531),
#  ('34', 1518),
#  ('保险', 1518),
#  ('小微', 1517),
#  ('财政', 1517),
#  ('公众', 1516),
#  ('结束', 1514),
#  ('改变', 1513),
#  ('三大', 1511),
#  ('才能', 1511),
#  ('一季度', 1510),
#  ('总量', 1510),
#  ('支出', 1508),
#  ('活力', 1507),
#  ('个股', 1506),
#  ('融入', 1506),
#  ('三年', 1500),
#  ('期限', 1500),
#  ('文件', 1498),
#  ('前期', 1494),
#  ('全新', 1491),
#  ('稳住', 1491),
#  ('日起', 1489),
#  ('案例', 1489),
#  ('生态环境', 1489),
#  ('更是', 1486),
#  ('切实', 1484),
#  ('评价', 1473),
#  ('股东', 1471),
#  ('保证', 1469),
#  ('英国', 1468),
#  ('基本面', 1467),
#  ('复苏', 1466),
#  ('效果', 1463),
#  ('售价', 1460),
#  ('终端', 1460),
#  ('内部', 1458),
#  ('应对', 1456),
#  ('流程', 1456),
#  ('一家', 1454),
#  ('接近', 1454),
#  ('常态', 1453),
#  ('二十大', 1452),
#  ('浙江', 1452),
#  ('量产', 1452),
#  ('高速公路', 1450),
#  ('土地', 1445),
#  ('意义', 1444),
#  ('天然气', 1442),
#  ('控股', 1439),
#  ('较为', 1437),
#  ('把握', 1435),
#  ('收购', 1435),
#  ('成效', 1432),
#  ('观点', 1431),
#  ('决策', 1430),
#  ('经历', 1429),
#  ('优秀', 1428),
#  ('面向', 1426),
#  ('400', 1425),
#  ('省份', 1425),
#  ('解决方案', 1425),
#  ('披露', 1424),
#  ('录取', 1422),
#  ('概率', 1420),
#  ('名单', 1419),
#  ('始终', 1418),
#  ('受益', 1417),
#  ('接种', 1414),
#  ('清洁', 1413),
#  ('航空', 1413),
#  ('图片', 1410),
#  ('37', 1409),
#  ('05', 1406),
#  ('事业', 1403),
#  ('调剂', 1403),
#  ('分享', 1402),
#  ('营商', 1401),
#  ('谋划', 1400),
#  ('股权', 1399),
#  ('优先', 1398),
#  ('吉利', 1395),
#  ('群体', 1395),
#  ('二季度', 1394),
#  ('首个', 1394),
#  ('收益', 1393),
#  ('粮食', 1390),
#  ('储备', 1389),
#  ('吸引', 1389),
#  ('研究院', 1389),
#  ('多年', 1387),
#  ('两年', 1386),
#  ('加工', 1383),
#  ('查看', 1383),
#  ('主任', 1382),
#  ('逻辑', 1379),
#  ('培养', 1378),
#  ('面积', 1378),
#  ('调查', 1377),
#  ('层面', 1376),
#  ('本周', 1376),
#  ('理论', 1375),
#  ('问界', 1375),
#  ('沈阳', 1370),
#  ('38', 1365),
#  ('风电', 1364),
#  ('货币', 1361),
#  ('云南', 1360),
#  ('进度', 1359),
#  ('一线', 1358),
#  ('合同', 1358),
#  ('回收', 1358),
#  ('账户', 1358),
#  ('期待', 1357),
#  ('干部', 1356),
#  ('石油', 1356),
#  ('销售额', 1356),
#  ('事件', 1354),
#  ('退还', 1354),
#  ('重大项目', 1351),
#  ('2000', 1350),
#  ('环保', 1350),
#  ('供需', 1348),
#  ('农产品', 1348),
#  ('应急', 1347),
#  ('lpr', 1346),
#  ('子公司', 1346),
#  ('施工', 1346),
#  ('人工智能', 1345),
#  ('外资', 1345),
#  ('动能', 1344),
#  ('一次性', 1339),
#  ...]

# %% [markdown]
# ## Out Class

# %%
df = pd.read_csv('/Users/fanhongrui/Library/CloudStorage/OneDrive-南京大学/学习（OneDrive）/俄乌战争全球叙事/dataset_filter_240109.csv', index_col=0, nrows=20000)

# %%
df
# Out:
#                   tweet_id  author_id  created_at  retweet_count  reply_count  \
# 0      1540451336876986373   15432891  2022-06-24              0          0.0
# 1      1516696238212661253   78567974  2022-04-20              1          1.0
# 2      1587766197298548738  145535271  2022-11-02              0          0.0
# 3      1586193152175529984  145535271  2022-10-29              0          0.0
# 4      1580452730212331520  145535271  2022-10-13              0          0.0
# ...                    ...        ...         ...            ...          ...
# 19995  1511048157773369352  148711787  2022-04-04              5         10.0
# 19996  1511026352392228878  148711787  2022-04-04              7         10.0
# 19997  1511018158030737417  148711787  2022-04-04              0          4.0
# 19998  1511017889347817473  148711787  2022-04-04              3          6.0
# 19999  1511013225898389526  148711787  2022-04-04              6          0.0
#
#        like_count  quote_count  \
# 0               0            0
# 1               0            0
# 2               2            0
# 3               5            0
# 4               3            0
# ...           ...          ...
# 19995          25            1
# 19996          42            2
# 19997          21            1
# 19998          20            1
# 19999           0            0
#
#                                                  en_text  \
# 0      Weekend selection: Zelensky was not prepared f...
# 1      The Ukrainian war, Charles Michel of Kiev, the...
# 2      The invention of the Shark drone is a new chap...
# 3      Will nuclear war be over? Those countries that...
# 4      Boys fight: Students fight in coaching center....
# ...                                                  ...
# 19995  As global protests mount over the killing of c...
# 19996  Lavrov: West tries to pin war crimes charges o...
# 19997  Foreign Minister of Ukraine: The West feeds th...
# 19998  Foreign Minister of Ukraine: We won the war in...
# 19999  RT <USER_MENTION_1>: Secret visit to #Putin af...
#
#                                            stanza_output  \
# 0      [[{'id': 1, 'text': 'Weekend', 'upos': 'NOUN',...
# 1      [[{'id': 1, 'text': 'The', 'upos': 'DET', 'xpo...
# 2      [[{'id': 1, 'text': 'The', 'upos': 'DET', 'xpo...
# 3      [[{'id': 1, 'text': 'Will', 'upos': 'AUX', 'xp...
# 4      [[{'id': 1, 'text': 'Boys', 'upos': 'NOUN', 'x...
# ...                                                  ...
# 19995  [[{'id': 1, 'text': 'As', 'upos': 'SCONJ', 'xp...
# 19996  [[{'id': 1, 'text': 'Lavrov', 'upos': 'PROPN',...
# 19997  [[{'id': 1, 'text': 'Foreign', 'upos': 'ADJ', ...
# 19998  [[{'id': 1, 'text': 'Foreign', 'upos': 'ADJ', ...
# 19999  [[{'id': 1, 'text': 'RT', 'upos': 'PROPN', 'xp...
#
#                                    stanza_named_entities  ...    purity  \
# 0      [{'text': 'Zelensky', 'type': 'PERSON', 'start...  ...  0.072048
# 1      [{'text': 'The Ukrainian war', 'type': 'EVENT'...  ...  0.070797
# 2      [{'text': 'Shark', 'type': 'PRODUCT', 'start_c...  ...  0.015667
# 3                                                     []  ...  0.071667
# 4      [{'text': 'Russia', 'type': 'GPE', 'start_char...  ...  0.242989
# ...                                                  ...  ...       ...
# 19995  [{'text': 'Ukrainian', 'type': 'NORP', 'start_...  ...  0.981130
# 19996  [{'text': 'Lavrov', 'type': 'PERSON', 'start_c...  ...  0.073034
# 19997  [{'text': 'Ukraine', 'type': 'GPE', 'start_cha...  ...  0.753040
# 19998  [{'text': 'Ukraine', 'type': 'GPE', 'start_cha...  ...  0.851866
# 19999  [{'text': 'USER_MENTION_1', 'type': 'PERSON', ...  ...  0.052353
#
#       non-moral    mdate  ordinal_mdate  stance_pro_rus  stance_pro_ukr  \
# 0      0.617735  2022-06              4               0               0
# 1      0.606203  2022-04              2               0               0
# 2      0.614123  2022-11              9               0               0
# 3      0.614273  2022-10              8               0               0
# 4      0.621450  2022-10              8               0               1
# ...         ...      ...            ...             ...             ...
# 19995  0.555679  2022-04              2               0               1
# 19996  0.626474  2022-04              2               0               1
# 19997  0.355078  2022-04              2               0               1
# 19998  0.371231  2022-04              2               0               1
# 19999  0.324069  2022-04              2               1               0
#
#        stance_unsure  sentiment_negative  sentiment_neutral  \
# 0                  1                   0                  1
# 1                  1                   0                  1
# 2                  1                   0                  1
# 3                  1                   1                  0
# 4                  0                   1                  0
# ...              ...                 ...                ...
# 19995              0                   1                  0
# 19996              0                   1                  0
# 19997              0                   0                  1
# 19998              0                   0                  1
# 19999              0                   0                  1
#
#        sentiment_positive
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ...                   ...
# 19995                   0
# 19996                   0
# 19997                   0
# 19998                   0
# 19999                   0
#
# [20000 rows x 46 columns]

# %%
df.en_text[:100].sum()
# Out:
# 'Weekend selection: Zelensky was not prepared for war, Ukrainian director is not afraid of deathThe Ukrainian war, Charles Michel of Kiev, the summit with Volodymyr Zelensky, the Ukrainian president, theThe invention of the Shark drone is a new chapter in the war. #Russia #Ukraine #RussiaUkraineWarWill nuclear war be over? Those countries that are building bunkers.. #WarBunkers #BombShelters #NucleBoys fight: Students fight in coaching center.. cause it is bigger than Russia-Ukraine war.. #Boysfight #trA key development in the Russia-Ukraine war was the Ukrainian forces blowing up a huge bridge in Crimea.#Ukrainewar #Russia #Hypersonic missiles attack in Ukraine.. 9 killed.. Jalen Skiy claims that Russia is attaIndia will work towards a settlement of the conflict. PM Modi with President of Ukraine #PMModi #Zelensky #WarG7 summit: The war in Ukraine is a major problem for the world: PM ModiRussia - Ukraine war: Plot to assassinate Russian President Putin! - TV9 #putin #russia #russiaukraineThis is what happens when Russia loses the war! Former diplomat on Putin\'s future <URL_1> #VladimirThe war in Ukraine is coming to an end! Can China be trusted? Does it really have the guts?China\'s Ukraine Peace plan: 12 points of the report to end the war!Russia-Ukraine war: India and China away from crucial voteWhy only Ukraine! The same reason why there is war everywhere in the world!Putin\'s shocking decision! An unexpected turn of events for the US #russia #UkraineRussiaWar #VThe war was started by the West: Putin\'s sensational commentsCan Modi convince Putin to stop the war?Arming Ukraine would be the end of the world. Russia warnsNo Doubt! Russia is the winner!: Putin <URL_1> #UkraineRussiaWar #russian #VladimirWe have seen the situation where people throw away a 650 page manifesto in the trash wherever they ask. Today there is a warUkraine war: Russian soldiers\' wives are encouraging rape: Zelensky\'s wifePutin is very close to winning the Mother Hero Award.Prime Minister Modi\'s keynote address at G20 summit, Ukraine war as the main topic.Ukrainian citizens\' satire on Russian troops #UkraineRussiaWar #russianarmy #ukrainerussia #Ukraine #The Russian military is now in the hands of the Ukrainian government, which is trying to force the country to join the war.Putin out by the end of the Russia-Ukraine war!Russian thugs call Indian Defence Minister a dirty bomb #DirtyBomb #ukrainerussiawar #RajnathSinghThe US President Joe Biden has warned Russia that using a dirty bomb would be an unforgivable mistake.66,000 soldiers killed. What a loss for Russia in the war with Ukraine!Putin warns that NATO military exercises are <URL_1> #NATO #UkraineRussiaWar #TeluguNews\'If NATO goes to war, the world will be in for a disaster\': Putin\'s strong warningTensions in Ukraine.. severe warnings issued to IndiansThe war in Ukraine: counter to Russia.. Nobel Peace Prize to Putin for his defeat!When there is a nuclear war... no hair conditioner. Putin warns #Russia #UkraineRussiaWar #ShampooRussia\'s move to avoid Ukraine is a strong warning to the WestIf the situation is like this, then civil war is going to happen.Another giant dies suspiciously, link to the Ukraine war!Russia\'s war games to check the sanctions of the superpowerRussia-Ukraine war: People digging graves in Ukraine.. why does it make your eyes water! #RussiaUkraine #TV9Ukrainian President Zelensky appeals to G-7 leaders to end the war #UkraineCrisis #G7SummitNo one wins in the Russia-Ukraine war. Key UN declaration #RussiaUkraineWar #unitednations #RussiaUkraThe situation could lead to World War III. Concern about the Ukraine-Russia war #Russia #Ukraine #RussianUkrainianRussia Ukraine ISRO: Russia-Ukraine war effect.. if that happens, will ISRO not have problems? #RussiaUkraineWarRussia - Ukraine War: Russia announces that the war in the region is over. #RussiaUkraineConflict #MariupRussia\'s nuclear threat to Ukraine is likely to be reduced if the war takes an unprecedented turn.  ...

# %%
tokenizer = TweetTokenizer()
lemmatizer = WordNetLemmatizer()

nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/fanhongrui/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'http\S+','',text)
    tokens = tokenizer.tokenize(text)
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token.isalpha() and token != 'rt' and token not in stop_words]
    return tokens

# %%
df['preprocessed_text'] = df['en_text'].apply(preprocess_text)

# %%
df.head()
# Out:
#               tweet_id  author_id  created_at  retweet_count  reply_count  \
# 0  1540451336876986373   15432891  2022-06-24              0          0.0
# 1  1516696238212661253   78567974  2022-04-20              1          1.0
# 2  1587766197298548738  145535271  2022-11-02              0          0.0
# 3  1586193152175529984  145535271  2022-10-29              0          0.0
# 4  1580452730212331520  145535271  2022-10-13              0          0.0
#
#    like_count  quote_count                                            en_text  \
# 0           0            0  Weekend selection: Zelensky was not prepared f...
# 1           0            0  The Ukrainian war, Charles Michel of Kiev, the...
# 2           2            0  The invention of the Shark drone is a new chap...
# 3           5            0  Will nuclear war be over? Those countries that...
# 4           3            0  Boys fight: Students fight in coaching center....
#
#                                        stanza_output  \
# 0  [[{'id': 1, 'text': 'Weekend', 'upos': 'NOUN',...
# 1  [[{'id': 1, 'text': 'The', 'upos': 'DET', 'xpo...
# 2  [[{'id': 1, 'text': 'The', 'upos': 'DET', 'xpo...
# 3  [[{'id': 1, 'text': 'Will', 'upos': 'AUX', 'xp...
# 4  [[{'id': 1, 'text': 'Boys', 'upos': 'NOUN', 'x...
#
#                                stanza_named_entities  ... non-moral    mdate  \
# 0  [{'text': 'Zelensky', 'type': 'PERSON', 'start...  ...  0.617735  2022-06
# 1  [{'text': 'The Ukrainian war', 'type': 'EVENT'...  ...  0.606203  2022-04
# 2  [{'text': 'Shark', 'type': 'PRODUCT', 'start_c...  ...  0.614123  2022-11
# 3                                                 []  ...  0.614273  2022-10
# 4  [{'text': 'Russia', 'type': 'GPE', 'start_char...  ...  0.621450  2022-10
#
#   ordinal_mdate  stance_pro_rus  stance_pro_ukr  stance_unsure  \
# 0             4               0               0              1
# 1             2               0               0              1
# 2             9               0               0              1
# 3             8               0               0              1
# 4             8               0               1              0
#
#    sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0                   0                  1                   0
# 1                   0                  1                   0
# 2                   0                  1                   0
# 3                   1                  0                   0
# 4                   1                  0                   0
#
#                                    preprocessed_text
# 0  [weekend, selection, zelensky, prepared, war, ...
# 1  [ukrainian, war, charles, michel, kiev, summit...
# 2       [invention, shark, drone, new, chapter, war]
# 3          [nuclear, war, country, building, bunker]
# 4  [boy, fight, student, fight, coaching, center,...
#
# [5 rows x 47 columns]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['preprocessed_text'].apply(lambda x:str(x)))

# %%
X.shape
# Out:
# (20000, 9148)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['aaqf', 'ab', 'aband', ..., 'çavuşoğlu', 'ōsuki', 'ōzawa'],
#       dtype=object)

# %%
feature_words = vectorizer.get_feature_names_out()

# %%
word_freq = dict(zip(feature_words,X.sum(axis=0).A1))

# %% [markdown]
# 查看全球媒体关于俄乌战争的最高频词汇

# %%
sorted(word_freq.items(),key = lambda x:x[1], reverse=True)
# Out:
# [('war', 15555),
#  ('ukraine', 8345),
#  ('russian', 4687),
#  ('russia', 3713),
#  ('ukrainian', 2855),
#  ('putin', 1379),
#  ('warns', 1357),
#  ('president', 1249),
#  ('end', 1194),
#  ('military', 945),
#  ('minister', 874),
#  ('crime', 815),
#  ('kiev', 809),
#  ('foreign', 807),
#  ('nuclear', 770),
#  ('weapon', 770),
#  ('since', 749),
#  ('country', 729),
#  ('world', 674),
#  ('nato', 655),
#  ('year', 646),
#  ('european', 601),
#  ('towards', 584),
#  ('troop', 574),
#  ('zelensky', 573),
#  ('first', 571),
#  ('attack', 559),
#  ('new', 557),
#  ('support', 549),
#  ('stop', 546),
#  ('moscow', 544),
#  ('defense', 543),
#  ('urgent', 519),
#  ('severodonetsk', 509),
#  ('state', 470),
#  ('force', 464),
#  ('call', 463),
#  ('missile', 449),
#  ('west', 444),
#  ('international', 441),
#  ('crisis', 439),
#  ('warning', 416),
#  ('biden', 413),
#  ('secretary', 408),
#  ('europe', 403),
#  ('sanction', 399),
#  ('security', 399),
#  ('could', 398),
#  ('day', 398),
#  ('city', 392),
#  ('official', 387),
#  ('price', 381),
#  ('due', 380),
#  ('un', 380),
#  ('food', 377),
#  ('washington', 372),
#  ('western', 367),
#  ('consequence', 360),
#  ('energy', 358),
#  ('global', 357),
#  ('must', 356),
#  ('say', 346),
#  ('time', 345),
#  ('month', 344),
#  ('general', 339),
#  ('soldier', 335),
#  ('german', 322),
#  ('continue', 309),
#  ('said', 297),
#  ('use', 297),
#  ('people', 295),
#  ('eu', 289),
#  ('may', 288),
#  ('started', 283),
#  ('army', 281),
#  ('ministry', 280),
#  ('one', 280),
#  ('intelligence', 276),
#  ('want', 276),
#  ('two', 272),
#  ('british', 268),
#  ('plan', 266),
#  ('million', 262),
#  ('china', 260),
#  ('start', 260),
#  ('killed', 257),
#  ('macron', 250),
#  ('supply', 249),
#  ('warned', 243),
#  ('win', 243),
#  ('began', 242),
#  ('oil', 238),
#  ('last', 234),
#  ('fighting', 230),
#  ('continues', 228),
#  ('peace', 228),
#  ('despite', 224),
#  ('conflict', 222),
#  ('change', 220),
#  ('economic', 220),
#  ('kremlin', 219),
#  ('region', 218),
#  ('control', 214),
#  ('announces', 211),
#  ('council', 209),
#  ('criminal', 208),
#  ('visit', 207),
#  ('arrest', 204),
#  ('civilian', 202),
#  ('political', 202),
#  ('report', 201),
#  ('tank', 200),
#  ('battle', 199),
#  ('accuses', 198),
#  ('economy', 198),
#  ('development', 196),
#  ('prisoner', 195),
#  ('united', 194),
#  ('long', 193),
#  ('lost', 192),
#  ('using', 191),
#  ('gas', 190),
#  ('bombing', 189),
#  ('talk', 189),
#  ('blinken', 188),
#  ('belarus', 187),
#  ('germany', 187),
#  ('beginning', 186),
#  ('french', 186),
#  ('loss', 186),
#  ('invasion', 184),
#  ('face', 183),
#  ('discus', 181),
#  ('warrant', 181),
#  ('billion', 180),
#  ('leader', 180),
#  ('medium', 180),
#  ('vladimir', 179),
#  ('take', 178),
#  ('would', 178),
#  ('effort', 176),
#  ('need', 176),
#  ('fear', 175),
#  ('possible', 174),
#  ('child', 173),
#  ('video', 173),
#  ('kherson', 171),
#  ('eastern', 169),
#  ('power', 169),
#  ('chinese', 167),
#  ('prime', 167),
#  ('situation', 166),
#  ('threat', 165),
#  ('anniversary', 164),
#  ('meeting', 164),
#  ('turkish', 162),
#  ('destroyed', 160),
#  ('caused', 158),
#  ('summit', 158),
#  ('detail', 156),
#  ('territory', 156),
#  ('lavrov', 152),
#  ('strike', 152),
#  ('street', 151),
#  ('court', 150),
#  ('advance', 149),
#  ('former', 149),
#  ('impact', 149),
#  ('help', 148),
#  ('iranian', 148),
#  ('risk', 148),
#  ('arm', 147),
#  ('grain', 147),
#  ('drone', 145),
#  ('escalation', 144),
#  ('operation', 143),
#  ('affected', 142),
#  ('aid', 141),
#  ('amid', 140),
#  ('victory', 140),
#  ('border', 139),
#  ('plant', 138),
#  ('ready', 138),
#  ('scenario', 138),
#  ('analyst', 137),
#  ('arabic', 137),
#  ('house', 135),
#  ('demand', 132),
#  ('donbas', 131),
#  ('committed', 130),
#  ('course', 130),
#  ('way', 130),
#  ('issue', 129),
#  ('occupier', 129),
#  ('chancellor', 128),
#  ('changed', 128),
#  ('number', 128),
#  ('policy', 128),
#  ('erdogan', 127),
#  ('journalist', 126),
#  ('negotiation', 125),
#  ('statement', 125),
#  ('system', 125),
#  ('confirms', 124),
#  ('iran', 124),
#  ('target', 124),
#  ('without', 124),
#  ('commission', 123),
#  ('turn', 123),
#  ('arab', 122),
#  ('ally', 121),
#  ('make', 121),
#  ('turning', 121),
#  ('air', 120),
#  ('cost', 120),
#  ('heavy', 120),
#  ('reveals', 120),
#  ('sea', 120),
#  ('side', 120),
#  ('american', 119),
#  ('donetsk', 119),
#  ('latest', 119),
#  ('authority', 118),
#  ('export', 118),
#  ('head', 117),
#  ('march', 117),
#  ('position', 117),
#  ('preparing', 117),
#  ('ambassador', 116),
#  ('front', 116),
#  ('supplying', 116),
#  ('targeting', 116),
#  ('company', 115),
#  ('union', 115),
#  ('made', 114),
#  ('thousand', 114),
#  ('destruction', 113),
#  ('high', 113),
#  ('trying', 113),
#  ('warn', 113),
#  ('still', 112),
#  ('uk', 112),
#  ('week', 112),
#  ('attempt', 111),
#  ('goal', 111),
#  ('going', 111),
#  ('threatens', 111),
#  ('white', 111),
#  ('decision', 110),
#  ('expert', 110),
#  ('pentagon', 110),
#  ('used', 110),
#  ('warship', 110),
#  ('zelinsky', 110),
#  ('life', 109),
#  ('move', 109),
#  ('near', 109),
#  ('phase', 109),
#  ('refugee', 109),
#  ('role', 109),
#  ('sending', 108),
#  ('three', 108),
#  ('warehouse', 108),
#  ('another', 107),
#  ('pressure', 107),
#  ('major', 106),
#  ('next', 106),
#  ('danger', 105),
#  ('fighter', 105),
#  ('schultz', 105),
#  ('strategic', 105),
#  ('wheat', 105),
#  ('launch', 104),
#  ('market', 104),
#  ('counterpart', 103),
#  ('future', 103),
#  ('including', 103),
#  ('news', 103),
#  ('britain', 102),
#  ('evidence', 102),
#  ('many', 102),
#  ('soon', 102),
#  ('warplane', 102),
#  ('back', 101),
#  ('bomb', 101),
#  ('special', 100),
#  ('warhead', 100),
#  ('around', 99),
#  ('become', 99),
#  ('exchange', 99),
#  ('go', 99),
#  ('seek', 99),
#  ('show', 99),
#  ('area', 98),
#  ('department', 98),
#  ('federation', 98),
#  ('guterres', 98),
#  ('involvement', 98),
#  ('right', 98),
#  ('several', 98),
#  ('according', 97),
#  ('affect', 97),
#  ('black', 97),
#  ('important', 97),
#  ('kharkiv', 97),
#  ('national', 97),
#  ('put', 97),
#  ('ending', 96),
#  ('mariupol', 96),
#  ('second', 96),
#  ('winter', 96),
#  ('biggest', 95),
#  ('defence', 95),
#  ('lead', 95),
#  ('mean', 95),
#  ('government', 94),
#  ('johnson', 94),
#  ('point', 94),
#  ('step', 94),
#  ('advisor', 93),
#  ('france', 93),
#  ('relation', 93),
#  ('called', 92),
#  ('see', 92),
#  ('capital', 91),
#  ('crimea', 91),
#  ('enters', 91),
#  ('zaporizhia', 91),
#  ('document', 90),
#  ('hold', 90),
#  ('line', 90),
#  ('launched', 89),
#  ('today', 89),
#  ('turkey', 89),
#  ('forward', 88),
#  ('human', 88),
#  ('island', 88),
#  ('america', 87),
#  ('solution', 87),
#  ('action', 86),
#  ('direct', 86),
#  ('east', 86),
#  ('fire', 86),
#  ('committing', 85),
#  ('give', 85),
#  ('meet', 85),
#  ('reporter', 85),
#  ('effect', 84),
#  ('increase', 84),
#  ('lugansk', 84),
#  ('pm', 84),
#  ('third', 83),
#  ('coming', 82),
#  ('deputy', 82),
#  ('return', 82),
#  ('announced', 81),
#  ('avoid', 81),
#  ('citizen', 81),
#  ('death', 81),
#  ('four', 81),
#  ('infrastructure', 81),
#  ('odessa', 81),
#  ('prevent', 81),
#  ('dangerous', 80),
#  ('ongoing', 80),
#  ('pay', 80),
#  ('response', 80),
#  ('supporting', 80),
#  ('thwarted', 80),
#  ('wagner', 80),
#  ('bank', 79),
#  ('offensive', 79),
#  ('order', 79),
#  ('part', 79),
#  ('think', 79),
#  ('waging', 79),
#  ('interest', 78),
#  ('investigation', 78),
#  ('mobilization', 78),
#  ('outbreak', 78),
#  ('party', 78),
#  ('continuing', 77),
#  ('information', 77),
#  ('open', 77),
#  ('saudi', 77),
#  ('syria', 77),
#  ('fight', 76),
#  ('rise', 76),
#  ('url', 76),
#  ('diplomatic', 75),
#  ('director', 75),
#  ('know', 75),
#  ('serious', 75),
#  ('agreement', 74),
#  ('group', 74),
#  ('hour', 74),
#  ('humanitarian', 74),
#  ('phone', 74),
#  ('provide', 74),
#  ('taken', 74),
#  ('aggression', 73),
#  ('involved', 73),
#  ('largest', 73),
#  ('warfare', 73),
#  ('work', 73),
#  ('already', 72),
#  ('stoltenberg', 72),
#  ('told', 72),
#  ('difficult', 71),
#  ('huge', 71),
#  ('moving', 71),
#  ('possibility', 71),
#  ('belief', 70),
#  ('hope', 70),
#  ('responsible', 70),
#  ('center', 69),
#  ('diplomat', 69),
#  ('follow', 69),
#  ('diplomacy', 68),
#  ('hit', 68),
#  ('inflation', 68),
#  ('poland', 68),
#  ('prepare', 68),
#  ('sign', 68),
#  ('volodymyr', 68),
#  ('displaced', 67),
#  ('left', 67),
#  ('send', 67),
#  ('suffering', 67),
#  ('working', 67),
#  ('equipment', 66),
#  ('governor', 66),
#  ('result', 66),
#  ('staff', 66),
#  ('bakhmut', 65),
#  ('chief', 65),
#  ('fall', 65),
#  ('joe', 65),
#  ('look', 65),
#  ('plane', 65),
#  ('armed', 64),
#  ('big', 64),
#  ('come', 64),
#  ('cut', 64),
#  ('icc', 64),
#  ('injured', 64),
#  ('israel', 64),
#  ('reach', 64),
#  ('woman', 64),
#  ('beijing', 63),
#  ('cannot', 63),
#  ('explosion', 63),
#  ('facing', 63),
#  ('protest', 63),
#  ('real', 63),
#  ('shortage', 63),
#  ('south', 63),
#  ('break', 62),
#  ('commander', 62),
#  ('declaration', 62),
#  ('declares', 62),
#  ('entered', 62),
#  ('issued', 62),
#  ('law', 62),
#  ('live', 62),
#  ('looking', 62),
#  ('reason', 62),
#  ('speech', 62),
#  ('withdraw', 62),
#  ('catastrophic', 61),
#  ('clear', 61),
#  ('condition', 61),
#  ('deal', 61),
#  ('dialogue', 61),
#  ('finance', 61),
#  ('hundred', 61),
#  ('impose', 61),
#  ('israeli', 61),
#  ('join', 61),
#  ('light', 61),
#  ('prosecutor', 61),
#  ('rising', 61),
#  ('stand', 61),
#  ('strategy', 61),
#  ('accusation', 60),
#  ('administration', 60),
#  ('dead', 60),
#  ('declared', 60),
#  ('egypt', 60),
#  ('event', 60),
#  ('february', 60),
#  ('full', 60),
#  ('ground', 60),
#  ('parliament', 60),
#  ('taking', 60),
#  ('half', 59),
#  ('accountable', 58),
#  ('continued', 58),
#  ('failed', 58),
#  ('get', 58),
#  ('level', 58),
#  ('syrian', 58),
#  ('try', 58),
#  ('accused', 57),
#  ('condemn', 57),
#  ('everything', 57),
#  ('famine', 57),
#  ('leave', 57),
#  ('raise', 57),
#  ('zone', 57),
#  ('affair', 56),
#  ('ammunition', 56),
#  ('brutal', 56),
#  ('challenge', 56),
#  ('financial', 56),
#  ('india', 56),
#  ('member', 56),
#  ('providing', 56),
#  ('regime', 56),
#  ('stance', 56),
#  ('station', 56),
#  ('tension', 56),
#  ('trial', 56),
#  ('turned', 56),
#  ('urge', 56),
#  ('able', 55),
#  ('agency', 55),
#  ('disaster', 55),
#  ('five', 55),
#  ('medvedev', 55),
#  ('mistake', 55),
#  ('production', 55),
#  ('six', 55),
#  ('aware', 54),
#  ('comment', 54),
#  ('confrontation', 54),
#  ('envoy', 54),
#  ('fired', 54),
#  ('forced', 54),
#  ('like', 54),
#  ('secret', 54),
#  ('southern', 54),
#  ('top', 54),
#  ('advancing', 53),
#  ('ban', 53),
#  ('concern', 53),
#  ('denies', 53),
#  ('even', 53),
#  ('great', 53),
#  ('link', 53),
#  ('watch', 53),
#  ('artillery', 52),
#  ('belarusian', 52),
#  ('expect', 52),
#  ('finland', 52),
#  ('fleeing', 52),
#  ('presidency', 52),
#  ('prison', 52),
#  ('prominent', 52),
#  ('resolution', 52),
#  ('sent', 52),
#  ('trade', 52),
#  ('claim', 51),
#  ('expects', 51),
#  ('facility', 51),
#  ('fuel', 51),
#  ('hybrid', 51),
#  ('mohammad', 51),
#  ('package', 51),
#  ('satellite', 51),
#  ('spokesman', 51),
#  ('vehicle', 51),
#  ('victim', 51),
#  ('wounded', 51),
#  ('borrell', 50),
#  ('considers', 50),
#  ('entering', 50),
#  ('fallout', 50),
#  ('health', 50),
#  ('leaked', 50),
#  ('pope', 50),
#  ('port', 50),
#  ('repercussion', 50),
#  ('representative', 50),
#  ('track', 50),
#  ('almost', 49),
#  ('approach', 49),
#  ('bridge', 49),
#  ('bring', 49),
#  ('central', 49),
#  ('discussed', 49),
#  ('enter', 49),
#  ('increased', 49),
#  ('problem', 49),
#  ('scene', 49),
#  ('allow', 48),
#  ('held', 48),
#  ('longer', 48),
#  ('lose', 48),
#  ('post', 48),
#  ('senior', 48),
#  ('shelling', 48),
#  ('asks', 47),
#  ('history', 47),
#  ('influence', 47),
#  ('least', 47),
#  ('reuters', 47),
#  ('stopped', 47),
#  ('us', 47),
#  ('withdrawal', 47),
#  ('within', 47),
#  ('word', 47),
#  ('carrying', 46),
#  ('climate', 46),
#  ('euro', 46),
#  ('file', 46),
#  ('immediately', 46),
#  ('london', 46),
#  ('message', 46),
#  ('nation', 46),
#  ('north', 46),
#  ('office', 46),
#  ('polish', 46),
#  ('prepares', 46),
#  ('shown', 46),
#  ('wall', 46),
#  ('believe', 45),
#  ('car', 45),
#  ('current', 45),
#  ('emergency', 45),
#  ('every', 45),
#  ('fate', 45),
#  ('fled', 45),
#  ('import', 45),
#  ('luhansk', 45),
#  ('massive', 45),
#  ('planning', 45),
#  ('proposal', 45),
#  ('seeking', 45),
#  ('seen', 45),
#  ('town', 45),
#  ('wave', 45),
#  ('calling', 44),
#  ('case', 44),
#  ('catastrophe', 44),
#  ('chemical', 44),
#  ('embassy', 44),
#  ('far', 44),
#  ('heading', 44),
#  ('hunger', 44),
#  ('led', 44),
#  ('resident', 44),
#  ('rule', 44),
#  ('ship', 44),
#  ('shot', 44),
#  ('study', 44),
#  ('tried', 44),
#  ('trt', 44),
#  ('urgently', 44),
#  ('violent', 44),
#  ('balance', 43),
#  ('cause', 43),
#  ('damage', 43),
#  ('decided', 43),
#  ('directly', 43),
#  ('especially', 43),
#  ('everyone', 43),
#  ('much', 43),
#  ('push', 43),
#  ('source', 43),
#  ('story', 43),
#  ('term', 43),
#  ('winner', 43),
#  ('york', 43),
#  ('additional', 42),
#  ('attrition', 42),
#  ('ceasefire', 42),
#  ('close', 42),
#  ('fund', 42),
#  ('importance', 42),
#  ('justice', 42),
#  ('old', 42),
#  ('pushing', 42),
#  ('table', 42),
#  ('unprecedented', 42),
#  ('whole', 42),
#  ('arabia', 41),
#  ('bakhmot', 41),
#  ('enemy', 41),
#  ('main', 41),
#  ('making', 41),
#  ('mayor', 41),
#  ('organization', 41),
#  ('prolong', 41),
#  ('promise', 41),
#  ('recent', 41),
#  ('sergei', 41),
#  ('treasury', 41),
#  ('africa', 40),
#  ('also', 40),
#  ('broke', 40),
#  ('commissioner', 40),
#  ('delivery', 40),
#  ('expected', 40),
#  ('express', 40),
#  ('highlight', 40),
#  ('holding', 40),
#  ('intention', 40),
#  ('key', 40),
#  ('land', 40),
#  ('learn', 40),
#  ('nearly', 40),
#  ('prepared', 40),
#  ('raging', 40),
#  ('surprise', 40),
#  ('water', 40),
#  ('yet', 40),
#  ('chairman', 39),
#  ('defeat', 39),
#  ('dollar', 39),
#  ('drag', 39),
#  ('francis', 39),
#  ('getting', 39),
#  ('hand', 39),
#  ('home', 39),
#  ('journal', 39),
#  ('killing', 39),
#  ('loses', 39),
#  ('record', 39),
#  ('reject', 39),
#  ('respond', 39),
#  ('sector', 39),
#  ('threatened', 39),
#  ('zaporozhye', 39),
#  ('borel', 38),
#  ('cia', 38),
#  ('cnn', 38),
#  ('conference', 38),
#  ('considering', 38),
#  ('continent', 38),
#  ('cyber', 38),
#  ('growing', 38),
#  ('lady', 38),
#  ('losing', 38),
#  ('magazine', 38),
#  ('modern', 38),
#  ('mykolaiv', 38),
#  ('photo', 38),
#  ('separatist', 38),
#  ('settlement', 38),
#  ('sweden', 38),
#  ('tomorrow', 38),
#  ('training', 38),
#  ('unjustified', 38),
#  ('alliance', 37),
#  ('counterattack', 37),
#  ('delegate', 37),
#  ('dirty', 37),
#  ('likely', 37),
#  ('moment', 37),
#  ('negotiating', 37),
#  ('pledge', 37),
#  ('tactic', 37),
#  ('tell', 37),
#  ('aftermath', 36),
#  ('amnesty', 36),
#  ('causing', 36),
#  ('cooperation', 36),
#  ('critical', 36),
#  ('declare', 36),
#  ('dr', 36),
#  ('inside', 36),
#  ('middle', 36),
#  ('opportunity', 36),
#  ('place', 36),
#  ('predicts', 36),
#  ('presidential', 36),
#  ('professor', 36),
#  ('protect', 36),
#  ('responsibility', 36),
#  ('strong', 36),
#  ('ability', 35),
#  ('act', 35),
#  ('african', 35),
#  ('airstrikes', 35),
#  ('came', 35),
#  ('clock', 35),
#  ('counter', 35),
#  ('escape', 35),
#  ('hungarian', 35),
#  ('imf', 35),
#  ('mediation', 35),
#  ('mission', 35),
#  ('monday', 35),
#  ('newspaper', 35),
#  ('preparation', 35),
#  ('received', 35),
#  ('red', 35),
#  ('release', 35),
#  ('reported', 35),
#  ('reserve', 35),
#  ('resistance', 35),
#  ('xi', 35),
#  ('achieve', 34),
#  ('adviser', 34),
#  ('away', 34),
#  ('community', 34),
#  ('defend', 34),
#  ('destroying', 34),
#  ('duma', 34),
#  ('failure', 34),
#  ('iii', 34),
#  ('illegal', 34),
#  ('image', 34),
#  ('independence', 34),
#  ('large', 34),
#  ('machine', 34),
#  ('option', 34),
#  ('rate', 34),
#  ('reached', 34),
#  ('set', 34),
#  ('specter', 34),
#  ('spread', 34),
#  ('thursday', 34),
#  ('together', 34),
#  ('train', 34),
#  ('writer', 34),
#  ('amount', 33),
#  ('backdrop', 33),
#  ('begun', 33),
#  ('building', 33),
#  ('capability', 33),
#  ('chain', 33),
#  ('changing', 33),
#  ('civil', 33),
#  ('entire', 33),
#  ('focus', 33),
#  ('gain', 33),
#  ('italian', 33),
#  ('jet', 33),
#  ('joint', 33),
#  ('partner', 33),
#  ('population', 33),
#  ('returned', 33),
#  ('saying', 33),
#  ('service', 33),
#  ('stopping', 33),
#  ('stress', 33),
#  ('tragedy', 33),
#  ('wednesday', 33),
#  ('welcome', 33),
#  ('worst', 33),
#  ('achieved', 32),
#  ('admits', 32),
#  ('assembly', 32),
#  ('attitude', 32),
#  ('awarded', 32),
#  ('begin', 32),
#  ('berlin', 32),
#  ('brought', 32),
#  ('chechen', 32),
#  ('clash', 32),
#  ('cold', 32),
#  ('describes', 32),
#  ('escalate', 32),
#  ('family', 32),
#  ('field', 32),
#  ('hospital', 32),
#  ('industry', 32),
#  ('rage', 32),
#  ('republic', 32),
#  ('researcher', 32),
#  ('reveal', 32),
#  ('sale', 32),
#  ('stated', 32),
#  ('suffered', 32),
#  ('total', 32),
#  ('tribunal', 32),
#  ('advanced', 31),
#  ('behind', 31),
#  ('benefit', 31),
#  ('billionaire', 31),
#  ('capable', 31),
#  ('condemns', 31),
#  ('create', 31),
#  ('desire', 31),
#  ('destroy', 31),
#  ('dmitry', 31),
#  ('estimate', 31),
#  ('fierce', 31),
#  ('found', 31),
#  ('happening', 31),
#  ('historic', 31),
#  ('initiative', 31),
#  ('living', 31),
#  ('participate', 31),
#  ('press', 31),
#  ('program', 31),
#  ('refuse', 31),
#  ('reward', 31),
#  ('risen', 31),
#  ('shell', 31),
#  ('terrorist', 31),
#  ('trump', 31),
#  ('tv', 31),
#  ('unit', 31),
#  ('violation', 31),
#  ('volunteer', 31),
#  ('agree', 30),
#  ('alone', 30),
#  ('among', 30),
#  ('baltic', 30),
#  ('completely', 30),
#  ('continuation', 30),
#  ('czech', 30),
#  ('different', 30),
#  ('expand', 30),
#  ('factory', 30),
#  ('good', 30),
#  ('increasing', 30),
#  ('jens', 30),
#  ('night', 30),
#  ('officer', 30),
#  ('pandemic', 30),
#  ('police', 30),
#  ('question', 30),
#  ('soviet', 30),
#  ('taiwan', 30),
#  ('threatening', 30),
#  ('thwart', 30),
#  ('ago', 29),
#  ('asked', 29),
#  ('asset', 29),
#  ('battlefield', 29),
#  ('best', 29),
#  ('blockade', 29),
#  ('chance', 29),
#  ('consider', 29),
#  ('contact', 29),
#  ('enough', 29),
#  ('eye', 29),
#  ('final', 29),
#  ('following', 29),
#  ('forecast', 29),
#  ('funding', 29),
#  ('horror', 29),
#  ('immediate', 29),
#  ('imposed', 29),
#  ('interview', 29),
#  ('keep', 29),
#  ('lack', 29),
#  ('mass', 29),
#  ('never', 29),
#  ('occupied', 29),
#  ('progress', 29),
#  ('proposes', 29),
#  ('provided', 29),
#  ('regional', 29),
#  ('related', 29),
#  ('resolve', 29),
#  ('tuesday', 29),
#  ('arrives', 28),
#  ('award', 28),
#  ('bombardment', 28),
#  ('campaign', 28),
#  ('casualty', 28),
#  ('channel', 28),
#  ('committee', 28),
#  ('confirm', 28),
#  ('der', 28),
#  ('door', 28),
#  ('double', 28),
#  ('given', 28),
#  ('happen', 28),
#  ('humanity', 28),
#  ('investigate', 28),
#  ('investigator', 28),
#  ('korea', 28),
#  ('map', 28),
#  ('minute', 28),
#  ('occupation', 28),
#  ('opening', 28),
#  ('others', 28),
#  ('paris', 28),
#  ('past', 28),
#  ('retreat', 28),
#  ('sky', 28),
#  ('tide', 28),
#  ('unity', 28),
#  ('waged', 28),
#  ('waiting', 28),
#  ('whether', 28),
#  ('based', 27),
#  ('bill', 27),
#  ('body', 27),
#  ('cap', 27),
#  ('concerned', 27),
#  ('devastating', 27),
#  ('eve', 27),
#  ('exercise', 27),
#  ...]
